# %% [markdown]
# Привет, меня зовут Артем Хуршудов. Сегодня я проверю твой проект.
# <br> Дальнейшее общение будет происходить на "ты" если это не вызывает никаких проблем.
# <br> Желательно реагировать на каждый мой комментарий ('исправил', 'не понятно как исправить ошибку', ...)
# <br> Пожалуйста, не удаляй комментарии ревьюера, так как они повышают качество повторного ревью.
#
# Комментарии будут в <font color='green'>зеленой</font>, <font color='blue'>синей</font> или <font color='red'>красной</font> рамках:
#
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Если все сделано отлично
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет: </b> Если можно немного улучшить
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Если требуются исправления. Работа не может быть принята с красными комментариями.
# </div>
#
# -------------------
#
# Будет очень хорошо, если ты будешь помечать свои действия следующим образом:
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> ...
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Были внесены следующие изменения ...
# </div>
#
# #### <font color='orange'>Полезные ссылки:</font>
# * Полезная лекция про временные ряды: https://www.youtube.com/watch?v=u433nrxdf5k .
#
# ### <font color='orange'>Общее впечатление</font>
# * Большое спасибо за проделанную работу. Видно, что приложено много усилий.
# * Отлично, что ноутбук хорошо структурирован. Приятно проверять такие работы.
# * Над этим проектом нужно будет еще немного поработать. Однако, изменения не должны занять много времени.
# * В работе я оставил несколько советов. Буду рад, если ты учтешь их.
# * С радостью отвечу на твои вопросы, если они есть. Лучше всего их собрать в следующей ячейке. Жду новую версию проекта.

# %% [markdown]
# <div style="color: black; background-color: #FFC373; padding: 10px 20px;">
#
# Привет, Артём спасибо за проверку моего проекта<br>
# Это первый раз за пол года когда проверили работу так быстро<br>
# Не хочу тебя перехваливать, наверное совпало)<br>
#
# Постарался исправить все замечания, но может и не вышло <br>
#
# В исправленной работе удалил фильтрацию по размаху усатому и добавил новые признаки<br>
# Скорректировал период сезона и удалил фичи которые, посчитал незначительными<br>
#
# Добавил в `optuna` кросс-валидацию для `CatBoost` так посмотреть, но смысла нет ниже описал причины<br>
# Переделал деления на выборки с максимальным изолированием от утечек<br>
#
# В результате `CatBoost` отрабатывает лучше всего на валидации, но не на тесте<br>
# На тесте лучше всех `LineRegression`<br>
#
# </div>

# %% [markdown]
# ### <font color='orange'>Общее впечатление (ревью 2)</font>
# * Для удобства все новые комментарии обозначены фразой "ревью 2".
# * Удачи в доработке!

# %% [markdown]
# ### <font color='orange'>Общее впечатление (ревью 3)</font>
# * Все новые комментарии обозначены фразой "ревью 3".
#
#
# ### <font color='orange'>Общее впечатление (ревью 4)</font>
# * Новый комментарий обозначен фразой "ревью 4".

# %% [markdown]
# ### <font color='orange'>Общее впечатление (ревью 5)</font>
# * Проект зачтен.
# * Удачи в дальнейшем обучении и следующих работах!

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Полезные-ссылки:" data-toc-modified-id="Полезные-ссылки:-0.0.1"><span class="toc-item-num">0.0.1&nbsp;&nbsp;</span><font color="orange">Полезные ссылки:</font></a></span></li></ul></li><li><span><a href="#Общее-впечатление" data-toc-modified-id="Общее-впечатление-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span><font color="orange">Общее впечатление</font></a></span></li><li><span><a href="#Общее-впечатление-(ревью-2)" data-toc-modified-id="Общее-впечатление-(ревью-2)-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span><font color="orange">Общее впечатление (ревью 2)</font></a></span></li><li><span><a href="#Общее-впечатление-(ревью-3)" data-toc-modified-id="Общее-впечатление-(ревью-3)-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span><font color="orange">Общее впечатление (ревью 3)</font></a></span></li><li><span><a href="#Общее-впечатление-(ревью-4)" data-toc-modified-id="Общее-впечатление-(ревью-4)-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span><font color="orange">Общее впечатление (ревью 4)</font></a></span></li><li><span><a href="#Общее-впечатление-(ревью-5)" data-toc-modified-id="Общее-впечатление-(ревью-5)-0.5"><span class="toc-item-num">0.5&nbsp;&nbsp;</span><font color="orange">Общее впечатление (ревью 5)</font></a></span></li></ul></li><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#XGBRegressor" data-toc-modified-id="XGBRegressor-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>XGBRegressor</a></span></li><li><span><a href="#XGBoost" data-toc-modified-id="XGBoost-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>XGBoost</a></span></li><li><span><a href="#CatBoostRegressor" data-toc-modified-id="CatBoostRegressor-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>CatBoostRegressor</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вывод-финал" data-toc-modified-id="Вывод-финал-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод финал</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# # Цель
# Построить модель прогназирования количества заказов на следующий час<br>
# Для компании «Чётенькое такси» для планирования бесперебойной работы <br>
#
#  - Значение метрики RMSE на тестовой выборке должно быть не больше 48
#
#  Данные располагаются https://code.s3.yandex.net/datasets/taxi.csv<br>
#  Целевой признак `num_orders` количество заказов<br>

# %% [markdown]
# ## Подготовка

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from plotly.subplots import make_subplots

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
try:
    import xgboost
    import lightgbm
except:
    # %pip install xgboost
    # %pip install lightgbm

# %%
from catboost import Pool, CatBoostRegressor
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit
from lightgbm import LGBMRegressor
import lightgbm as lgb
from sklearn.linear_model import LinearRegression
from sklearn.metrics import make_scorer, r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
try:
    import optuna
except:
    # %pip install optuna
    import optuna
    from optuna.integration import LightGBMPruningCallback

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Отлично, что все импорты собраны в верхней чатси ноутбука! Если у того, кто будет запускать твой ноутбук будут отсутствовать некоторые библиотеки, то он это увидит сразу, а не в процессе!
# </div>

# %%
try:
    data = pd.read_csv('taxi.csv', index_col='datetime', parse_dates=[0])

except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/taxi.csv', index_col='datetime', parse_dates=[0])
data.sort_index(inplace=True)

# %%
# зададим константы
NAME_DATA = 'taxi.csv'
RANDOM_STATE = 6568

# %%
def isna_count_procent(data, name):
    '''
    Создадим таблицу с пропусками в  дата сете
    Всего три столбца 
    1. процентное отношение пропусков к длине
    2. количество пропусков в единицах
    3. тип
    Далее блок выводит всю доступную информацию о данных 
    Несколько первых строк
    Описание числовых признаков
    Описание категориальных признаков
    
    '''
    pd.set_option('display.max_rows', None)
    isna_columns = data.isna().sum() > 0
    type_ = pd.DataFrame(data[data.isna().sum()[isna_columns].index.tolist()].dtypes)[0]
    isna_columns = pd.DataFrame([data.isna().sum()[isna_columns]/data.shape[0], data.isna().sum()[isna_columns]]).T
    isna_columns = isna_columns.rename(columns={0: 'procent', 1: 'count'})
    # isna_columns['type'] = type_[0]
    isna_columns['count'] = isna_columns['count'].map('{:,.2f}'.format)
    isna_columns['procent'] = isna_columns['procent'].map('{:,.2%}'.format)
    isna_columns = isna_columns.sort_values('procent', ascending=False)
    # блок показывае всё о данных
    display(data.head(5))
    print('#'*55)
    print()
    display(data.describe(include=np.number))
    print()
    # display(data.describe(include=np.object_))
    print('#'*55)
    print()
    data.info()
    print('#'*55)
    isna = data.isna().sum().sum()
    isna_procent = len(isna_columns)/data.shape[1]
    s = data.duplicated().sum()
    print(f'Количество дубликатов в данных  равно {s}')
    print()
    print(f'Всего пропусков в {name} {isna:,} шт. в {len(isna_columns)} столбцах')
    print(f'В процентном отношении {isna_procent:.2%} от {data.shape[1]:,} признаков')
  
    print()
    display(isna_columns)
    return isna_columns

# %%
isna_count_procent(data, NAME_DATA)
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# #######################################################
#          num_orders
# count  26496.000000
# mean      14.070463
# std        9.211330
# min        0.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max      119.000000
# #######################################################
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB
# #######################################################
# Количество дубликатов в данных  равно 26415
#
# ...

# %% [markdown]
# ### Вывод
# Датафрейм `taxi` содержит один столбец `num_orders` это целевой признак в формате `int64`<br>
# Индекс в формате `datetime от 2018-03-01 до 2018-08-31` всего 26496 объектов<br>
# Пропуски отсутствуют, данные отсортированы по индексу<br>

# %% [markdown]
# ## Анализ

# %%
data = data.resample('1h').sum()

# %% [markdown]
# Построим график заказов

# %%
fig, ax = plt.subplots(figsize=(9, 3))
data.plot(style='.', ax=ax, title='Количество заказов в час');

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Данные загружены корректно, первичный осмотр проведен. Ресемплинг был сделан верно.
# </div>

# %% [markdown]
# Количество заказов по всему временному отрезку выглядит стационарно<br>
# С небольшим увеличением количества заказов в конце августа<br><br>
# Проверим сезонность и тренд<br>
# Построим график понедельно установив предварительно начало недели понедельник

# %%
decompose = seasonal_decompose(data, model='additive', period=24)

fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9), (ax10, ax11, ax12)) = plt.subplots(4,3, figsize=(20,10));

fig.subplots_adjust(hspace=0.5)
decompose.seasonal.loc['2018-06-04':'2018-06-10'].plot(ax=ax1, style='-')
decompose.trend.loc['2018-06-04':'2018-06-10'].plot(ax=ax2)
decompose.resid.loc['2018-06-04':'2018-06-10'].plot(ax=ax3)

decompose.seasonal.loc['2018-06-11':'2018-06-17'].plot(ax=ax4, style='-')
decompose.trend.loc['2018-06-11':'2018-06-17'].plot(ax=ax5)
decompose.resid.loc['2018-06-11':'2018-06-17'].plot(ax=ax6)

decompose.seasonal.loc['2018-06-18':'2018-06-24'].plot(ax=ax7, style='-')
decompose.trend.loc['2018-06-18':'2018-06-24'].plot(ax=ax8)
decompose.resid.loc['2018-06-18':'2018-06-24'].plot(ax=ax9)

decompose.seasonal.loc['2018-06-25':'2018-07-01'].plot(ax=ax10, style='-')
decompose.trend.loc['2018-06-25':'2018-07-01'].plot(ax=ax11)
decompose.resid.loc['2018-06-25':'2018-07-01'].plot(ax=ax12)
b = 9
c = 3
for num in [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12]:
    remainder = b % c
    num.set_xlabel('')
    if remainder == 0:
        num.set_title('Сезонность в июне по неделям')
    elif remainder == 1:
        num.set_title('Тренд в июне по неделям')
    elif remainder == 2:
        num.set_title('Остаток в июне по неделям')
    b += 1

# %% [markdown]
# Видим, что сезонность имеет дневные циклы распределённые по времени суток<br>
# Тренд колеблется в течение недели имеет несколько вершин <br>
# Линия тренда по дням недели имеет схожие черты построим наши признаки основываясь на данных за прошедшую неделю<br>
# Остаток имеет стационарный вид<br>
# Добавим эти признаки в наш датафрейм они помогут обучиться моделям лучше<br>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Не нужно изменять period. Какой смысл в 365 часах?
# </div>

# %% [markdown]
# <div style="color: black; background-color: #FFC373; padding: 10px 20px;">
#     <strong>Поправил</strong><br>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Во всех графиках в проекте нужно подписать оси и названия, чтобы было понятно, что на нем визуализировано.
# </div>

# %% [markdown]
# <div style="color: black; background-color: #FFC373; padding: 10px 20px;">
#     <strong>Поправил</strong><br>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех (ревью 2):</b> Отлично!
# </div>

# %% [markdown]
# Создадим ещё признаков для нашего датафрейма<br>
# Выделим из индекса недели и месяц<br>
# Построим несколько признаков соответствующие количеству за предшествующие недели<br>
# И несколько отстающих признаков

# %%
def make_features(X, lag):
    for i in range(1, 5):
        X['lag_{}'.format(i)] = X['num_orders'].shift(lag * i)
    
    X['week'] = X.index.week
    X['month'] = X.index.month
    return X

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка (ревью 2):</b> Нельзя добавлять признак diff и его производные, так как это приводит к утечке (diff вычисляется с использованием текущего значения). Можно добавить сдвиг (shift), как в с лучае с rolling_mean.
# </div>

# %% [markdown]
# <div style="color: black; background-color: #FFC373; padding: 10px 20px;">
#     <strong>Возражаю  &#x1F600;</strong><br>
#
# Данные были предварительно разделены на три выборки X_train, X_valid, X_test, <br>
#     и каждая из них обрабатывалась отдельно, можно утверждать, что утечка данных не было<br>
#
# Потому, что признаки для каждой выборки создавались на основе данных только из этой выборки<br>
#     а не на основе данных из других выборок, что исключало возможность утечки информации из тестовой выборки в обучающую или проверочную выборки<br><br>
#     Кроме этого!<br>
#     Строка X['mean_std'] = (difference.mean() - difference.rolling(window=15).mean()) / difference.rolling(window=15).std()<br>
#     Создает новый признак mean_std, который представляет собой стандартизированное значение разности между текущим значением ряда и его средним значением на предыдущих 15 временных точках<br>
# <br>
# Этот признак не содержит информацию о будущих значениях целевой переменной и не может быть использован для определения значений в будущем<br>
#     Поэтому это не должно приводить к утечке информации<br>
#     <br>
#     Как бы ни было я всё переписал, но осадочек остался

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Совет (ревью 3): </b> Утечка происходит не между треин/валид/тест, а внутри каждого. Признак diff = current - prev. Значение current – это целевое значение, оно нам неизвестно в момент предсказаний, то есть его нельзя использовать при создании признаков. Именно поэтому мы и добавляли сдвиги (shift), чтобы избавиться от этой проблемы.
# </div>

# %% [markdown]
# Функция для добавления признаков сезонность и тренд

# %%
def decomp(data, decompose=decompose):
    data['seasonal'] = decompose.seasonal.shift()
    data['trend'] = decompose.trend.shift()

    return data

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Совет: </b> Желательно было написать функцию таким образом, чтобы она возвращала новый датафрейм, а не изменяла глобальную переменную.
# 1. Это хорошая практика (не изменять глобальные переменные внутри функции), которая улучшает читаемость кода.
# 2. В какой-то момент может появиться необходимость подбирать некоторые параметры используемый внутри функции. В этот момент копирование датасета станет обязательным.
# </div>

# %% [markdown]
# <div style="color: black; background-color: #FFC373; padding: 10px 20px;">
#     <strong>Поправил первый пункт</strong><br>
# Не понял второго пункта, в какой момент, какие параметры подбирать, ты о чем?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Совет (ревью 2): </b> Параметры max_lag и rolling_mean_size. Их тоже можно подобрать на кросс-валидаации.
# </div>

# %% [markdown]
# Создадим новые признаки

# %%
lag = 24 * 7

data = make_features(data.copy(), lag)

# %% [markdown]
# Поделим на выборки сразу и будем работать с ними<br>

# %%
signs = data.drop(columns='num_orders', axis=1).copy()
target = data['num_orders'].copy()

X_train, X_test, y_train, y_test = train_test_split(signs, target, train_size=0.9, shuffle=False, random_state=RANDOM_STATE)

# %%
X_train = decomp(X_train) 
X_test = decomp(X_test)

# %%
isna_columns = isna_count_procent(X_train, NAME_DATA)
# Out:
#                      lag_1  lag_2  lag_3  lag_4  week  month   seasonal  trend
# datetime
# 2018-03-01 00:00:00    NaN    NaN    NaN    NaN     9      3  60.248112    NaN
# 2018-03-01 01:00:00    NaN    NaN    NaN    NaN     9      3  20.177074    NaN
# 2018-03-01 02:00:00    NaN    NaN    NaN    NaN     9      3  28.982743    NaN
# 2018-03-01 03:00:00    NaN    NaN    NaN    NaN     9      3  17.885407    NaN
# 2018-03-01 04:00:00    NaN    NaN    NaN    NaN     9      3   2.791145    NaN
# #######################################################
#              lag_1        lag_2        lag_3        lag_4         week  \
# count  3806.000000  3638.000000  3470.000000  3302.000000  3974.000000
# mean     76.704940    75.382353    73.751585    72.347971    20.752391
# std      37.227375    36.537652    35.561152    34.791826     6.835089
# min       0.000000     0.000000     0.000000     0.000000     9.000000
# 25%      51.000000    51.000000    50.000000    49.000000    15.000000
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка (ревью 3):</b> Признаки trend и seasonal тоже нельзя добавлять без сдвига, абсолютно по той же причине, что и дифф. Они считаеются с использованием текущего значения. МОжешь добавить еще и остатки и тогда получить скор равный нулю (так как сезонность+тренд+остатки и есть целевая колонка).
# </div>

# %% [markdown]
# <div style="color: black; background-color: #FFC373; padding: 10px 20px;">
# Какой это абсурд, Артём?! Уже третья проверка, и ячейка была написана с самого начала. Концепция декомпозиции - одна из основных тем этого блока о временных рядах. Ты уже второй раз проверил, и только сейчас заметил, что что-то там не так?! Весь этот процесс неприятен, особенно когда понимаешь, что это банальная лень и невнимательность.
#
# Все имеют право на ошибку, но важно об этом говорить. Имею в виду, что ты то же имеешь такое право.
#     Качество твоей проверки - самое низкое за все время! Я говорю не о твоих профессиональных качествах в области data science, а о коммуникативных навыках. Ты даешь объяснение только после того, как я переспрашиваю. Вроде того – здесь ошибка, так нельзя! Почему, это ошибка, почему так нельзя? Сразу не рассказываешь
#
# Может быть, ты забыл, что мы все еще студенты?

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка (ревью 4):</b> Я согласен, что ошибся и не заметил это в первом ревью. Далее, ты переносил эту ячейку в разные места и при повторных ревью я это тоже не сразу заметил. Прошу прощения.
#
# Желательно создавать признаки в одном месте (функции make_features), а не в разных местах в коде. В любом случае, эту ошибку необходимо исправить. Это может сказать на итоговом качестве, для его улучшения стоит увеличить параметр max_lag.
#
# Про объяснение не могу с тобой согласиться: в первом же ревью (по номеру оно было вторым), где ты добавил признаки diff я подробно объяснил, почему так нельзя: "нельзя добавлять признак diff и его производные, так как это приводит к утечке (diff вычисляется с использованием текущего значения). Можно добавить сдвиг (shift), как в случае с rolling_mean." Напомню, что в первой итерации признаков diff не было. Абсолютно также и со всеми другими ошибками (напр. выбросами), было объяснение, почему так нельзя делать.
# </div>

# %% [markdown]
# <div style="color: black; background-color: #FFC373; padding: 10px 20px;">
#     Привет я не понимаю что ты от меня хочешь конкретно сейчас я всё исправил декомпозиция со сдвигом отстающие признаки сделаны как надо!
#     Я попросил отправить мою работу на разбор

# %% [markdown]
# Удалим строчки с пропусками все пропуски расположены вначале и в конце таблицы<br>
# Поэтому непрерывность временного ряда сохраниться<br>

# %%
X_train.dropna(subset=isna_columns.index, inplace=True)
X_test.dropna(subset=isna_columns.index, inplace=True)

# %%
y_train = pd.DataFrame(y_train, index=X_train.index)
y_test = pd.DataFrame(y_test, index=X_test.index)

# %%
isna_count_procent(X_test, NAME_DATA)
# Out:
#                      lag_1  lag_2  lag_3  lag_4  week  month   seasonal  \
# datetime
# 2018-08-13 14:00:00   98.0   84.0   86.0   64.0    33      8  -9.191665
# 2018-08-13 15:00:00  117.0   91.0  118.0   94.0    33      8   3.731832
# 2018-08-13 16:00:00  204.0  127.0  127.0  124.0    33      8  29.604100
# 2018-08-13 17:00:00  133.0  156.0  136.0  123.0    33      8   7.920016
# 2018-08-13 18:00:00   85.0   78.0   73.0   59.0    33      8 -15.527958
#
#                           trend
# datetime
# 2018-08-13 14:00:00  130.354167
# 2018-08-13 15:00:00  123.958333
# 2018-08-13 16:00:00  124.333333
# 2018-08-13 17:00:00  123.500000
# 2018-08-13 18:00:00  122.312500
# #######################################################
#             lag_1       lag_2       lag_3       lag_4        week  month  \
# count  430.000000  430.000000  430.000000  430.000000  430.000000  430.0
# mean   123.513953  113.132558  107.109302  105.018605   33.893023    8.0
# ...

# %%
def corr_psk(data):
    fig, (ax, ax1, ax2) = plt.subplots(3, 1, figsize=(12, 14))
    plt.subplots_adjust(hspace=0.2)
    sns.heatmap(data=data.corr(), annot=True, ax=ax) \
        .set_title('Корреляция Пирсона', weight='bold', size='large');
    sns.heatmap(data=data.corr(method='spearman'), annot=True, ax=ax1) \
        .set_title('Корреляция Спирмена', weight='bold', size='large');
    sns.heatmap(data=data.corr(method='kendall'), annot=True, ax=ax2) \
        .set_title('Корреляция Кенделла', weight='bold', size='large');
#     sns.heatmap(data=data.phik_matrix(interval_cols=data.columns), annot=True, ax=ax3) \
#         .set_title('Корреляция $\phi_K$', weight='bold', size='large');

    plt.show()

# %% [markdown]
# Оценим связь признаков с целевым признаком посмотрим на корреляцию

# %%
corr_psk(X_train.join(y_train['num_orders']))

# %% [markdown]
# Корреляция признаков `lag` очень высокая по Пирсаны и по Спирмену<br>
# Остальные признаки по Спирмену и Пирсану имеют корреляцию в диапазоне от слабой до средней <br>

# %% [markdown]
# Посмотрим на выбросы

# %%
def moustache_box(data, x,x1, y):   
    sns.set_theme()
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,3));
    fig.subplots_adjust(wspace=0.1)
    sns.boxenplot(data=data, x=x, y=y, ax=ax1);
    ax1.set_title('Ящик с усами по неделям и заказам');
    sns.boxenplot(data=data, x=x1, y=y, ax=ax2);
    ax2.set_title('Ящик с усами по месяцам и заказам');
    
    plt.show()

# %%
moustache_box(data=X_train, x='week', x1='month', y=y_train['num_orders'])

# %% [markdown]
# Среднее количество заказов несильно, но стабильно увеличивается с каждой неделей<br>
# Месячный график ящика с усами также показывает увеличение количества заказов с каждым месяцем<br>
# Очевидно у нас возрастающий тренд<br>

# %% [markdown]
# ### Вывод
#
# Создали и добавили признаки в таблицу<br>
# Построили таблицу корреляции относительно таргета<br>
# Всего получилось 9 признаков вместе с целевым<br>
# Корреляция признаков в диапазоне от средней до сильной <br>
# <br>
# Два признака созданы с использованием библиотеки `seasonal_decompose`<br>
# `'seasonal', 'trend'` <br>
# Остальные признаки это <br>
# `'week', 'month'` взяты из временного ряда таблицы<br>
# Отстающие признаки `'lag_1', 'lag_2', 'lag_3','lag_4'` смещены каждая на неделю<br>
# И соответствуют значениям которые были в этот час неделю наз, две недели назад и т.д.
# <br>
# Сезонность имеет дневные циклы распределённые по времени суток<br>
# Тренд колеблется в течение недели имеет несколько вершин <br>
# Остаток имеет стационарный вид<br>
# <br>
# Удалили строчки с пропусками все пропуски расположены вначале и в конце таблицы<br>
# Поэтому непрерывность временного ряда сохранилась<br>
# <br>
# Среднее количество заказов несильно, но стабильно увеличивается с каждой неделей<br>
# Месячный график ящика с усами также показывает увеличение количества заказов с каждым месяцем<br>
# Очевидно у нас возрастающий тренд<br>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Без причины удалять выбросы нельзя. нужно доказать, что это ошибки. В данном случае это не удается доказать, так как есть просто количество заказов.
# </div>

# %% [markdown]
# <div style="color: black; background-color: #FFC373; padding: 10px 20px;">
#     <strong>Поправил</strong>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех (ревью 2):</b> ОК.
# </div>

# %% [markdown]
# ## Обучение

# %% [markdown]
# Построим график и посмотрим выборки и их последовательность

# %%
fig, ax = plt.subplots(figsize=(10,3));

y_train.plot(ax=ax, style='.');
# y_valid.plot(ax=ax, style='.');
y_test.plot(ax=ax, style='.');
ax.legend(['X_train', 'X_test']);
ax.set_title('Последовательность выборок');
plt.show()

# %% [markdown]
# Выборки располагаются последовательно<br>
# Отлично мы так и планировали<br>
# <br>
#
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Разбиение было сделано корректно.
# </div>
#
# Масштабируем выборки

# %%
scaler = StandardScaler().fit(X_train)

X_train = pd.DataFrame(scaler.transform(X_train), columns=[X_train.columns])
X_test = pd.DataFrame(scaler.transform(X_test), columns=[X_test.columns])
X_train.head()
# Out:
#       lag_1     lag_2     lag_3     lag_4      week     month  seasonal  \
# 0  1.582948  1.245849  1.919922  1.484827 -1.716634 -2.007873  2.301940
# 1  0.565907  0.209808  0.091559  0.363705 -1.716634 -2.007873  0.771350
# 2 -1.387882 -0.608120 -0.274114 -0.038750 -1.716634 -2.007873  1.107699
# 3 -0.129963 -0.962555 -0.189728 -0.182483 -1.716634 -2.007873  0.683815
# 4 -1.468175 -1.698690 -0.414757 -0.843658 -1.716634 -2.007873  0.107261
#
#       trend
# 0 -1.350384
# 1 -1.348118
# 2 -1.334520
# 3 -1.303926
# 4 -1.230273

# %% [markdown]
# Подготовили данные обучим несколько моделей<br>
# Метрика для качества mean_squared_error в простонародье RMSE<br>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Отлично, что scaler был обучен только на треине!
# </div>

# %% [markdown]
# ### LinearRegression

# %%
# %%time
optuna.logging.disable_default_handler()


def objective(trial):
    fit_intercept = trial.suggest_categorical('fit_intercept', [True, False])
    normalize = trial.suggest_categorical('normalize', [True, False])
    copy_X = trial.suggest_categorical('copy_X', [True, False])

    tscv = TimeSeriesSplit(n_splits=2)

    # Initialize empty list for RMSE scores
    rmse_scores = []

    # Loop over splits
    for train_index, valid_index in tscv.split(X_train):
        # Split data
        X_train_fold, X_valid_fold = X_train.iloc[train_index], X_train.iloc[valid_index]
        y_train_fold, y_valid_fold = y_train.iloc[train_index], y_train.iloc[valid_index]

        # Train model
        model = LinearRegression(fit_intercept=fit_intercept, copy_X=copy_X, normalize=normalize)
        model.fit(X_train_fold, y_train_fold)

        # Evaluate model on validation set
        y_pred_fold = model.predict(X_valid_fold)
        rmse_fold = mean_squared_error(y_valid_fold, y_pred_fold, squared=False)
        rmse_scores.append(rmse_fold)

    # Return average RMSE score over splits
    return np.mean(rmse_scores)
LR_study = optuna.create_study(direction='minimize')
LR_study.optimize(objective, n_trials=8)
print(f"Best parameters: {LR_study.best_params}")
print(f"Best score: {LR_study.best_value:.2f}")
# Out:
# Best parameters: {'fit_intercept': True, 'normalize': False, 'copy_X': True}
# Best score: 21.67
# CPU times: user 229 ms, sys: 18.3 ms, total: 248 ms
# Wall time: 130 ms

# %% [markdown]
# Отлично, сходу попали в хорошее качество на валидационной выборке<br>
# Продолжим и обучим ещё пару моделей градиентного спуска

# %% [markdown]
# ### XGBRegressor

# %%
# %%time

# define the objective function for Optuna
def objective(trial):
    # define the hyperparameters to search
    params = {
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.5),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'n_estimators': trial.suggest_int('n_estimators', 50, 5000),
        'subsample': trial.suggest_uniform('subsample', 0.1, 1),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.1, 1),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-6, 10),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-6, 10),
        'random_state': RANDOM_STATE
    }
    # define the model

    tscv = TimeSeriesSplit(n_splits=2)

    # Initialize empty list for RMSE scores
    rmse_scores = []

    # Loop over splits
    for train_index, valid_index in tscv.split(X_train):
        # Split data
        X_train_fold, X_valid_fold = X_train.iloc[train_index], X_train.iloc[valid_index]
        y_train_fold, y_valid_fold = y_train.iloc[train_index], y_train.iloc[valid_index]

        # Train model
        model = XGBRegressor(**params)
        model.fit(X_train_fold, y_train_fold)

        # Evaluate model on validation set
        y_pred_fold = model.predict(X_valid_fold)
        rmse_fold = mean_squared_error(y_valid_fold, y_pred_fold, squared=False)
        rmse_scores.append(rmse_fold)

    # Return average RMSE score over splits
    return np.mean(rmse_scores)

# define the Optuna study
XGBR_study = optuna.create_study(direction='minimize')
XGBR_study.optimize(objective, n_trials=10)


print("Best hyperparameters:", XGBR_study.best_params)
print("Best RMSE score:", XGBR_study.best_value)
# Out:
# Best hyperparameters: {'learning_rate': 0.0012441688875341787, 'max_depth': 6, 'n_estimators': 3769, 'subsample': 0.6004213431489791, 'colsample_bytree': 0.27010148841998993, 'reg_alpha': 0.014061736837652786, 'reg_lambda': 0.0035163445967888894}
# Best RMSE score: 23.280854541721336
# CPU times: user 2min 5s, sys: 1.78 s, total: 2min 7s
# Wall time: 34.3 s

# %% [markdown]
# ### XGBoost

# %%
# %%time

def objective(trial):

    params = {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'booster': 'gbtree',
        'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 0.1),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'subsample': trial.suggest_uniform('subsample', 0.5, 1),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1),
        'gamma': trial.suggest_uniform('gamma', 0, 1),
        'reg_alpha': trial.suggest_uniform('reg_alpha', 0, 1),
        'reg_lambda': trial.suggest_uniform('reg_lambda', 0, 1),
        'random_state': RANDOM_STATE,
        # 'tree_method': 'gpu_hist'
    }

        # Define TimeSeriesSplit with 3 splits
    tscv = TimeSeriesSplit(n_splits=2)

    # Initialize empty list for RMSE scores
    rmse_scores = []

    # Loop over splits
    for train_index, valid_index in tscv.split(X_train):
        # Split data
        X_train_fold, X_valid_fold = X_train.iloc[train_index], X_train.iloc[valid_index]
        y_train_fold, y_valid_fold = y_train.iloc[train_index], y_train.iloc[valid_index]
        
        dtrain = xgb.DMatrix(X_train_fold, label=y_train_fold)
        dvalid = xgb.DMatrix(X_valid_fold, label=y_valid_fold)
        # Train model
        bst = xgb.train(params=params, dtrain=dtrain, num_boost_round=10000, 
        evals=[(dvalid, 'eval')], early_stopping_rounds=100, verbose_eval=9000)
        
        y_pred_fold = bst.predict(dvalid)
        

        # Evaluate model on validation set
        
        rmse_fold = mean_squared_error(y_valid_fold, y_pred_fold, squared=False)
        rmse_scores.append(rmse_fold)

    # Return average RMSE score over splits
    return np.mean(rmse_scores)

# Optimize hyperparameters
XGB_study = optuna.create_study(direction='minimize')
XGB_study.optimize(objective, n_trials=10)

# Get best hyperparameters
print('Best hyperparameters: {}'.format(XGB_study.best_params))
print('Best RMSE: {:.4f}'.format(XGB_study.best_value))
# Out:
# [0]	eval-rmse:79.79662
# [145]	eval-rmse:22.07525
# [0]	eval-rmse:101.09645
# [136]	eval-rmse:26.75294
# [0]	eval-rmse:82.79886
# [171]	eval-rmse:20.84514
# [0]	eval-rmse:104.22048
# [155]	eval-rmse:26.71091
# [0]	eval-rmse:81.13205
# [183]	eval-rmse:21.51014
# [0]	eval-rmse:102.38935
# [136]	eval-rmse:28.16771
# [0]	eval-rmse:85.99398
# [353]	eval-rmse:21.15243
# [0]	eval-rmse:107.98885
# [255]	eval-rmse:26.02577
# [0]	eval-rmse:81.25881
# [170]	eval-rmse:22.03581
# [0]	eval-rmse:102.31542
# [145]	eval-rmse:26.69683
# [0]	eval-rmse:86.06160
# [344]	eval-rmse:20.87154
# [0]	eval-rmse:108.04868
# [292]	eval-rmse:25.69648
# [0]	eval-rmse:84.66217
# [227]	eval-rmse:21.54787
# [0]	eval-rmse:106.35012
# [194]	eval-rmse:26.84604
# [0]	eval-rmse:80.04921
# [133]	eval-rmse:22.01262
# [0]	eval-rmse:100.91726
# [130]	eval-rmse:28.26647
# [0]	eval-rmse:85.68299
# [279]	eval-rmse:20.69572
# [0]	eval-rmse:107.66550
# [247]	eval-rmse:26.31942
# [0]	eval-rmse:84.93275
# [249]	eval-rmse:20.73598
# ...

# %% [markdown]
# ### CatBoostRegressor

# %%
# %%time
# Define hyperparameters to optimize
def objective(trial):
    params = {
        'iterations': trial.suggest_int('iterations', 100, 2000),
        'learning_rate': trial.suggest_uniform('learning_rate', 0.001, 0.1),
        'depth': trial.suggest_int('depth', 3, 10),
        'l2_leaf_reg': trial.suggest_uniform('l2_leaf_reg', 0, 10),
        'border_count': trial.suggest_int('border_count', 32, 255),
        'random_strength': trial.suggest_uniform('random_strength', 0, 1),
        'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 1),
        'grow_policy': trial.suggest_categorical('grow_policy', ['SymmetricTree', 'Depthwise', 'Lossguide'])
    }

    # Define TimeSeriesSplit with 3 splits
    tscv = TimeSeriesSplit(n_splits=2)

    # Initialize empty list for RMSE scores
    rmse_scores = []

    # Loop over splits
    for train_index, valid_index in tscv.split(X_train):
        # Split data
        X_train_fold, X_valid_fold = X_train.iloc[train_index], X_train.iloc[valid_index]
        y_train_fold, y_valid_fold = y_train.iloc[train_index], y_train.iloc[valid_index]

        # Train model
        model = CatBoostRegressor(**params, random_state=RANDOM_STATE, eval_metric='RMSE')
        model.fit(X_train_fold, y_train_fold, eval_set=(X_valid_fold, y_valid_fold), verbose=False)

        # Evaluate model on validation set
        y_pred_fold = model.predict(X_valid_fold)
        rmse_fold = mean_squared_error(y_valid_fold, y_pred_fold, squared=False)
        rmse_scores.append(rmse_fold)

    # Return average RMSE score over splits
    return np.mean(rmse_scores)

# Optimize hyperparameters
cat_study = optuna.create_study(direction='minimize')
cat_study.optimize(objective, n_trials=5)

# Get best hyperparameters
print('Best hyperparameters: {}'.format(cat_study.best_params))
print('Best RMSE: {:.4f}'.format(cat_study.best_value))
# Out:
# Best hyperparameters: {'iterations': 719, 'learning_rate': 0.04455838351399107, 'depth': 4, 'l2_leaf_reg': 0.7739837809732897, 'border_count': 105, 'random_strength': 0.5362587954500214, 'bagging_temperature': 0.504894438682204, 'grow_policy': 'SymmetricTree'}
# Best RMSE: 22.5817
# CPU times: user 43.8 s, sys: 1.19 s, total: 45 s
# Wall time: 14.5 s

# %%
best_result_rmse = {'LinearRegression':f'{LR_study.best_value:.2F}',
                    'XGBRegressor': f'{XGBR_study.best_value:.2F}',
                     'XGBoost': f'{XGB_study.best_value:.2F}',
                    'CatBoostRegressor': f'{cat_study.best_value:.2F}'}
                    
#
best_result_rmse = pd.DataFrame([best_result_rmse], index=['best_scorr_rmse'])
best_result_rmse.T
# Out:
#                   best_scorr_rmse
# LinearRegression            21.67
# XGBRegressor                23.28
# XGBoost                     23.28
# CatBoostRegressor           22.58

# %% [markdown]
# ### Вывод
#
# На этапе обучения на тренировочной и проверочной выборках обучили четыре модели<br>
# `LinearRegression, XGBRegressor, XGBoost, CatBoostRegressor`<br>
# Все модели проходят по критерию качества с величиной ошибки RMSE меньше 48<br>
#
# Лучший результат с наименьшей ошибкой RMSE у модели `LinearRegression`<br>
#
# Для дальнейшего тестирования будем использовать `LinearRegression`

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Совет: </b> Можно было реализовать подбор параметров с помощью кросс-валидации. При работе с временными рядами нельзя использовать стандартную кросс-валидацию, так как в определенный момент тренировочная выборка окажется позже валидационной. Для решения этой проблемы стоит использовать <a href="https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html">TimeSeriesSplit</a>. Объект этого типа можно передать в параметр cv в метод основанный на кросс-валидации.
# </div>

# %% [markdown]
# <div style="color: black; background-color: #FFC373; padding: 10px 20px;">
# Можно было много еще чего сделать, например <a href="  https://alexanderdyakonov.wordpress.com/2017/03/10/c%d1%82%d0%b5%d0%ba%d0%b8%d0%bd%d0%b3-stacking-%d0%b8-%d0%b1%d0%bb%d0%b5%d0%bd%d0%b4%d0%b8%d0%bd%d0%b3-blending/">`Stacking`</a> для создания дополнительных признаков<br>
# Под капотом optuna имеет `RandomSearch, GridSearch` в качестве суррогатных функций <br>
# Соответственно и кросс-валидация есть для примера реализовал на CatBoost модели с использованием `TimeSeriesSplit.`<br>
# Но смысла конкретно в этом случае нет <br>
# Получается, что когда происходит кросс валидация и выборка делиться из-за того, что внутри выборки признаки были созданы<br>
# С использованием смещения, модель опосредовательно получает информацию из будущего за счет чего показывает хорошее качество<br>
# Но в реальных условия это не работает!<br>
#
# <br>
# Тесты показали, что методы кросс-валидации и байесовские алгоритмы приходят в одну точку подбора параметров<br>
# Но Баесовский поиск оптимизирован по времени за счет удаления «плохих» точек пространства из рассмотрения<br>
# Скорость его лучше, что видно в примере<br>
# </div>
# <img src='https://habrastorage.org/r/w1560/webt/2j/5p/eu/2j5peuaiuyqwoepxv_cfq-klyfy.jpeg' width="600" height="200">

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Совет (ревью 2): </b>
#
# > С использованием смещения, модель опосредовательно получает информацию из будущего за счет чего показывает хорошее качество Но в реальных условия это не работает!
#
# Это неверное утверждение. Чем кросс-валидация отличается от разбиения не треин и тест?
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Ошибка (ревью 2):</b> На тестовой выборке нужно измерить только одну – лучшую модель. Сравнение моделей нужно провести только на кросс-валидации (с одним и тем же параметром "cv") или только на валидационной выборке.
#
# Это, как раз, и есть причина завышенного качества катбуста. Скор катбуста нельзя сравнивать со скором других моделей, так как они замеры производились на разных выборках.
# </div>

# %% [markdown]
# <div style="color: black; background-color: #FFC373; padding: 10px 20px;">
#     <strong>Поправил</strong>

# %% [markdown]
# <div style="color: black; background-color: #FFC373; padding: 10px 20px;">
#     <strong>Давай сравним две половинки задницы и удивимся почему они до сих пор вместе невзирая на всё говно между ними</strong><br>
#     Разницы нет, признаю ошибся <br>
#     Про то, что нет разницы мне было понятно изначально<br>
#     Подумал так – мы создаем новый признак и как ты писал, ранее про кросс-валидацию, что в какой-то момент<br>
#     Выборка окажется впереди таргета и тут я поплыл<br>
#     При использовании TimeSeriesSplit нет этого эффекта<br>
# </div>

# %% [markdown]
# ## Тестирование

# %% [markdown]
# Модель `LineRegression` <br>
# Качество модели на валидации RMSE 21.67

# %%
LR_model = LinearRegression(**LR_study.best_params)
# %time LR_model.fit(X_train, y_train)

# %time LR_pred = LR_model.predict(X_test)
rmse = mean_squared_error(y_test, LR_pred, squared=False)

print('RMSE модели на тесте: {:.4f}'.format(rmse))
# Out:
# CPU times: user 5.42 ms, sys: 814 µs, total: 6.24 ms
# Wall time: 4.45 ms
# CPU times: user 1.9 ms, sys: 92 µs, total: 1.99 ms
# Wall time: 1.25 ms
# RMSE модели на тесте: 33.3442

# %%
LR_pred = pd.DataFrame(LR_pred, index=y_test.index)
# посторим график на котором сравним исходные таргеты и предсказания моделей
fig, (ax) = plt.subplots( figsize=(14, 4));
sns.lineplot(data=y_test, ax=ax).set_title('Сравнение целевой переменной и предсказания модели LineRegression')
sns.lineplot(data=LR_pred[0], ax=ax, label='LineRegr_pred')
plt.show()

# %% [markdown]
# Предсказание модели накладывается и повторяет конторы целевой переменной <br>
# Демонстрируя хорошее качество

# %% [markdown]
# ### Вывод
#
# Модель `LineRegression` успешно прошла тестирование <br>
# Качество модели соответствует заданым требованиям `RMSE` равен 33.3442<br>
# Создание модели по предсказанию спроса такси в аэторорту на следующий час закончино<br>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Тестирование было сделано корректно.
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет: </b> Финальные предсказания можно было визуализирвоать: графики исходного и предсказанных рядов.
# </div>

# %% [markdown]
# ## Вывод финал
#
# Для компании «Чётенькое такси» построили модель прогнозирования количества заказов на следующий час<br>
# Модель `LinearRegression` с настроенными параметрами сохраненные в переменной `LR_model`<br>
# Качество модели оценивали с помощью метрики `RMSE` величина которой на тестовой выборке равна 41<br>
# Что соответствует заданным параметрам "меньше 48"<br>
# <br>
# Для обучения модели было создано 10 признаков <br>
# Три признака созданы с использованием библиотеки `seasonal_decompose`<br>
# `'seasonal', 'trend'` <br>
# Остальные признаки это <br>
# `'week', 'month'` взятый из временного ряда таблицы<br>
# Отстающие признаки `'lag_1', 'lag_2', 'lag_3','lag_4'`<br>
# Признак `num_orders` целевой признак<br>
# Датафрейм был ресемплирован и значения `num_orders` суммированы по часу<br>
# <br>
# Признак `datetime` был отформатирован в `datetime64` формат и использован в качестве индекса<br>
# Индекс отсортирован и содержал непрерывные данные `datetime от 2018-03-01 до 2018-08-31` всего 26496 объектов<br>
# Пропуски отсутствуют<br>
# <br>
# На этапе обучения на тренировочной и проверочной выборках обучили четыре моделей<br>
# `LinearRegression, XGBRegressor, XGBoost, CatBoostRegressor`<br>
# Все модели проходят по критерию качества с величиной ошибки RMSE меньше 48 на валидационной выборке<br>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Приятно видеть вывод в конце проекта!
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [X]  Весь код выполняется без ошибок
# - [X]  Ячейки с кодом расположены в порядке исполнения
# - [X]  Данные загружены и подготовлены
# - [X]  Данные проанализированы
# - [X]  Модель обучена, гиперпараметры подобраны
# - [X]  Качество моделей проверено, выводы сделаны
# - [X]  Значение *RMSE* на тестовой выборке не больше 48
